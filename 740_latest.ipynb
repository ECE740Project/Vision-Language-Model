# %%
import os
import cv2
import torch
import numpy as np
from ultralytics import YOLO

# Directories
input_folder = 'C:/Users/kalya/Desktop/Desktop/ML/lama/lama/test_aug'
output_folder = 'C:/Users/kalya/Desktop/Desktop/ML/lama/lama'
augmented_folder = os.path.join(output_folder, 'augmented_images')
mask_folder = os.path.join(output_folder, 'masks')
objects_folder = os.path.join(output_folder, 'extracted_objects')

# Create directories if they don't exist
os.makedirs(augmented_folder, exist_ok=True)
os.makedirs(mask_folder, exist_ok=True)
os.makedirs(objects_folder, exist_ok=True)

# Load YOLOv8 model (consider a larger model if `yolov8n.pt` is too small)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# model = YOLO('yolov8l.pt') '' # Using medium model for potentially better accuracy
model = YOLO("yolo11n-seg.pt")
model.to(device)

# Gaussian noise function
def add_gaussian_noise(image, mean=0, std=25):
    noise = np.random.normal(mean, std, image.shape).astype(np.uint8)
    noisy_image = cv2.add(image, noise)
    return noisy_image

# Process each image in the input folder
# image_file = "ILSVRC2012_val_00000002.jpg"
image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]
ctr=0
for image_file in image_files:
    # Load the original image
    image_path = os.path.join(input_folder, image_file)
    image = cv2.imread(image_path)
    
    # Resize the image to 640x640 for YOLO
    resized_image = cv2.resize(image, (640, 640))
    ctr+=1
    # Object detection with lower confidence threshold
    results = model(resized_image, conf=0.2)  # Set lower confidence threshold for detections
    # results[0].show()
    # Get detections for the first image in results
    detections = results[0].boxes  # Access bounding boxes for the first image
    # Prepare mask for the detected objects (black background)
    mask = np.zeros(resized_image.shape[:2], dtype=np.uint8)
    
    # Loop through each detected object and get the bounding box coordinates
    for i, box in enumerate(detections):
        # Move bounding box data to CPU, then convert to integers
        x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
        confidence = box.conf.cpu().numpy()
        
        if confidence > 0.25:  # Lower confidence threshold
            # Extract object and save it
            if ctr%2 == 0:
                obj_image = resized_image[y1:y2, x1:x2]
                obj_image_with_noise = add_gaussian_noise(obj_image)
                obj_path = os.path.join(objects_folder, f'obj_{i}_{image_file}')
                cv2.imwrite(obj_path, obj_image)
            else:
                obj_image = resized_image[y1:y2, x1:x2]
                obj_path = os.path.join(objects_folder, f'obj_{i}_{image_file}')
                cv2.imwrite(obj_path, obj_image)
            # Draw bounding box on mask to indicate regions of interest (black inside objects)
            mask[y1:y2, x1:x2] = 255  # Black region for detected object on mask
            
    # Apply Gaussian noise to the original image after object derection and save
    augmented_image = add_gaussian_noise(resized_image)
    augmented_image_path = os.path.join(augmented_folder, f'{image_file}')
    cv2.imwrite(augmented_image_path, augmented_image)
    
    # Save the mask
    tmp=str(image_file)
    img = tmp.split(".")[0]
    num = tmp.split("e")[-1].split(".")[0]
    mask_path = os.path.join(mask_folder, f'{img}_mask{num}.png')
    cv2.imwrite(mask_path, mask)
    print(f"Processed {image_file}: Augmented image saved to {augmented_image_path}, Mask saved to {mask_path}, Objects saved in {objects_folder}")
print("Process Completed for all Images")
# Out:
# 0: 640x640 (no detections), 62.9ms
# Speed: 15.6ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Processed image1.png: Augmented image saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\augmented_images\image1.png, Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\masks\image1_mask1.png, Objects saved in C:/Users/kalya/Desktop/Desktop/ML/lama/lama\extracted_objects
#
# 0: 640x640 1 cow, 1 zebra, 35.2ms
# Speed: 16.5ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Processed image17.png: Augmented image saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\augmented_images\image17.png, Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\masks\image17_mask17.png, Objects saved in C:/Users/kalya/Desktop/Desktop/ML/lama/lama\extracted_objects
#
# 0: 640x640 1 bed, 31.7ms
# Speed: 14.3ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Processed image19.png: Augmented image saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\augmented_images\image19.png, Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\masks\image19_mask19.png, Objects saved in C:/Users/kalya/Desktop/Desktop/ML/lama/lama\extracted_objects
#
# 0: 640x640 2 persons, 2 skiss, 1 snowboard, 29.6ms
# Speed: 0.0ms preprocess, 29.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Processed image2.png: Augmented image saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\augmented_images\image2.png, Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\masks\image2_mask2.png, Objects saved in C:/Users/kalya/Desktop/Desktop/ML/lama/lama\extracted_objects
#
# 0: 640x640 (no detections), 23.8ms
# Speed: 9.5ms preprocess, 23.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Processed image20.png: Augmented image saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\augmented_images\image20.png, Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\masks\image20_mask20.png, Objects saved in C:/Users/kalya/Desktop/Desktop/ML/lama/lama\extracted_objects
#
# 0: 640x640 7 persons, 4 dogs, 3 sheeps, 31.3ms
# Speed: 2.2ms preprocess, 31.3ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# Processed image22.png: Augmented image saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\augmented_images\image22.png, Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\masks\image22_mask22.png, Objects saved in C:/Users/kalya/Desktop/Desktop/ML/lama/lama\extracted_objects
#
# 0: 640x640 1 dog, 36.5ms
# Speed: 0.8ms preprocess, 36.5ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
# Processed image3.png: Augmented image saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\augmented_images\image3.png, Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\masks\image3_mask3.png, Objects saved in C:/Users/kalya/Desktop/Desktop/ML/lama/lama\extracted_objects
#
# 0: 640x640 1 truck, 33.1ms
# Speed: 3.2ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Processed image35.png: Augmented image saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\augmented_images\image35.png, Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\masks\image35_mask35.png, Objects saved in C:/Users/kalya/Desktop/Desktop/ML/lama/lama\extracted_objects
#
# 0: 640x640 1 person, 36.3ms
# Speed: 0.7ms preprocess, 36.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
# Processed image59.png: Augmented image saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\augmented_images\image59.png, Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama\masks\image59_mask59.png, Objects saved in C:/Users/kalya/Desktop/Desktop/ML/lama/lama\extracted_objects
# Process Completed for all Images

# %%
# import cv2
# import numpy as np
# import os

# # Directory paths
# input_folder = 'C:/Users/kalya/Desktop/Desktop/ML/lama/lama/test_aug'
# output_folder = 'C:/Users/kalya/Desktop/Desktop/ML/lama/lama/output'
# augmented_folder = os.path.join(output_folder, 'augmented_images')
# mask_folder = os.path.join(output_folder, 'masks')
# objects_folder = os.path.join(output_folder, 'extracted_objects')

# # Create directories for output, masks, and objects
# os.makedirs(augmented_folder, exist_ok=True)
# os.makedirs(mask_folder, exist_ok=True)
# os.makedirs(objects_folder, exist_ok=True)
# os.makedirs(output_folder, exist_ok=True)

# # List of all images in the input folder
# image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]

# # Bounding box coordinates
# bbox = []
# drawing = False  # Flag to indicate if we're currently drawing the bounding box

# # Gaussian noise function
# def add_gaussian_noise(image, mean=0, std=25):
#     noise = np.random.normal(mean, std, image.shape).astype(np.uint8)
#     noisy_image = cv2.add(image, noise)
#     return noisy_image


# def draw_bbox(event, x, y, flags, param):
#     """Mouse callback function to draw bounding box dynamically."""
#     global bbox, drawing, image, clone

#     if event == cv2.EVENT_LBUTTONDOWN:
#         # Start drawing the bounding box
#         bbox = [(x, y)]
#         drawing = True

#     elif event == cv2.EVENT_MOUSEMOVE:
#         # Update the bounding box while the mouse is moving
#         if drawing:
#             temp_image = clone.copy()  # Copy of the original image to reset drawing on each move
#             cv2.rectangle(temp_image, bbox[0], (x, y), (0, 255, 0), 2)
#             cv2.imshow("Image", temp_image)

#     elif event == cv2.EVENT_LBUTTONUP:
#         # Finalize the bounding box
#         bbox.append((x, y))
#         drawing = False
#         cv2.rectangle(image, bbox[0], bbox[1], (0, 255, 0), 2)
#         cv2.imshow("Image", image)

# # Process each image in the folder
# ctr=0
# for image_file in image_files:
#     # Load the image
#     image_path = os.path.join(input_folder, image_file)
#     image = cv2.imread(image_path)
#     clone = image.copy()  # Keep a clone of the original image
#     bbox.clear()
    
#     # Display image and set mouse callback
#     cv2.namedWindow("Image")
#     cv2.setMouseCallback("Image", draw_bbox)
#     cv2.imshow("Image", image)
#     print(f"Draw a bounding box for {image_file} and press any key when done.")
    
#     # Wait for the user to draw the bounding box and press a key
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    
#     # Skip if bounding box is not drawn
#     if len(bbox) != 2:
#         print(f"Skipping {image_file} as no bounding box was drawn.")
#         # continue
    
#     # Create the mask
#     mask = np.zeros(image.shape[:2], dtype=np.uint8)
#     x0, y0 = bbox[0]
#     x1, y1 = bbox[1]
#     mask[y0:y1, x0:x1] = 255  # Set the bounding box region to white for inpainting
    
#     # Save the mask and object
#     mask_path = os.path.join(mask_folder, f'mask_{image_file}')
#     cv2.imwrite(mask_path, mask)
    
#     object_img = clone[y0:y1, x0:x1]
#     # Apply Gaussian noise to the original image after object derection and save
#     ctr+=1
#     if ctr%2==0:
#         augmented_object_image = add_gaussian_noise(object_img)
#         augmented_objects_folder_image_path = os.path.join(objects_folder, f'object_{image_file}')
#         cv2.imwrite(augmented_objects_folder_image_path, augmented_object_image)
#     else:
#         object_image_path = os.path.join(objects_folder, f'object_{object_img}')
#         cv2.imwrite(object_image_path, object_img)

#     # Always apply noise to the backround image
#     augmented_original_image = add_gaussian_noise(image_file)
#     augmented_image_path = os.path.join(augmented_folder, f'{image_file}')
#     cv2.imwrite(augmented_image_path, augmented_original_image)
    
#     print(f"Processed {image_file}: Mask saved to {mask_path}, Object saved to {object_path}")

# print("Processing complete for all images.")

# %% [markdown]
# ## Manual Selection of BB

# %%
import cv2
import numpy as np
import os

# Directory paths
input_folder = 'C:/Users/kalya/Desktop/Desktop/ML/lama/lama/test_aug'
output_folder = 'C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images'
augmented_folder = os.path.join(output_folder, 'augmented_images')
mask_folder = os.path.join(output_folder, 'masks')
objects_folder = os.path.join(output_folder, 'extracted_objects')

# Create directories for output, masks, and objects
os.makedirs(output_folder, exist_ok=True)
os.makedirs(augmented_folder, exist_ok=True)
os.makedirs(mask_folder, exist_ok=True)
os.makedirs(objects_folder, exist_ok=True)

# List of all images in the input folder
image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]

# Bounding box coordinates
bbox = []
drawing = False  # Flag to indicate if we're currently drawing the bounding box

# Gaussian noise function
def add_gaussian_noise(image, mean=0, std=25):
    noise = np.random.normal(mean, std, image.shape).astype(np.uint8)
    noisy_image = cv2.add(image, noise)
    return noisy_image

def draw_bbox(event, x, y, flags, param):
    """Mouse callback function to draw bounding box dynamically."""
    global bbox, drawing, image, clone

    if event == cv2.EVENT_LBUTTONDOWN:
        # Start drawing the bounding box
        bbox = [(x, y)]
        drawing = True

    elif event == cv2.EVENT_MOUSEMOVE:
        # Update the bounding box while the mouse is moving
        if drawing:
            temp_image = clone.copy()  # Copy of the original image to reset drawing on each move
            cv2.rectangle(temp_image, bbox[0], (x, y), (0, 255, 0), 2)
            cv2.imshow("Image", temp_image)

    elif event == cv2.EVENT_LBUTTONUP:
        # Finalize the bounding box
        bbox.append((x, y))
        drawing = False
        cv2.rectangle(image, bbox[0], bbox[1], (0, 255, 0), 2)
        cv2.imshow("Image", image)

# Process each image in the folder
ctr = 0
for image_file in image_files:
    # Load the image
    image_path = os.path.join(input_folder, image_file)
    image = cv2.imread(image_path)
    clone = image.copy()  # Keep a clone of the original image
    bbox.clear()
    
    # Display image and set mouse callback
    cv2.namedWindow("Image")
    cv2.setMouseCallback("Image", draw_bbox)
    cv2.imshow("Image", image)
    print(f"Draw a bounding box for {image_file} and press any key when done.")
    
    # Wait for the user to draw the bounding box and press a key
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    # Skip if bounding box is not drawn
    if len(bbox) != 2:
        print(f"Skipping {image_file} as no bounding box was drawn.")
        continue
    
    # Create the mask
    mask = np.zeros(image.shape[:2], dtype=np.uint8)
    x0, y0 = bbox[0]
    x1, y1 = bbox[1]
    mask[y0:y1, x0:x1] = 255  # Set the bounding box region to white for inpainting
    
    # Save the mask and object
    mask_path = os.path.join(mask_folder, f'mask_{os.path.splitext(image_file)[0]}.png')
    cv2.imwrite(mask_path, mask)
    
    object_img = clone[y0:y1, x0:x1]
    ctr += 1
    if ctr % 2 == 0:
        augmented_object_image = add_gaussian_noise(object_img)
        augmented_object_path = os.path.join(objects_folder, f'object_{os.path.splitext(image_file)[0]}_aug.png')
        cv2.imwrite(augmented_object_path, augmented_object_image)
    else:
        object_image_path = os.path.join(objects_folder, f'object_{os.path.splitext(image_file)[0]}.png')
        cv2.imwrite(object_image_path, object_img)

    # Add Gaussian noise to the background image
    augmented_original_image = add_gaussian_noise(clone)
    augmented_image_path = os.path.join(augmented_folder, f'{os.path.splitext(image_file)[0]}.png')
    cv2.imwrite(augmented_image_path, augmented_original_image)
    
    print(f"Processed {image_file}: Mask saved to {mask_path}, Object saved.")

print("Processing complete for all images.")
# Out:
# Draw a bounding box for image1.png and press any key when done.
# Processed image1.png: Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images\masks\mask_image1.png, Object saved.
# Draw a bounding box for image17.png and press any key when done.
# Processed image17.png: Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images\masks\mask_image17.png, Object saved.
# Draw a bounding box for image19.png and press any key when done.
# Processed image19.png: Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images\masks\mask_image19.png, Object saved.
# Draw a bounding box for image2.png and press any key when done.
# Processed image2.png: Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images\masks\mask_image2.png, Object saved.
# Draw a bounding box for image20.png and press any key when done.
# Processed image20.png: Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images\masks\mask_image20.png, Object saved.
# Draw a bounding box for image22.png and press any key when done.
# Processed image22.png: Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images\masks\mask_image22.png, Object saved.
# Draw a bounding box for image3.png and press any key when done.
# Processed image3.png: Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images\masks\mask_image3.png, Object saved.
# Draw a bounding box for image35.png and press any key when done.
# Processed image35.png: Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images\masks\mask_image35.png, Object saved.
# Draw a bounding box for image59.png and press any key when done.
# Processed image59.png: Mask saved to C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images\masks\mask_image59.png, Object saved.
# Processing complete for all images.

# %% [markdown]
# ## Model Object Detection

# %%
import cv2
import numpy as np
import os
from ultralytics import YOLO
import torch

# Directory paths
input_folder = 'C:/Users/kalya/Desktop/Desktop/ML/lama/lama/coco_val2017'
# input_folder = 'C:/Users/kalya/Desktop/Desktop/ML/lama/lama/test_aug'
output_folder = 'C:/Users/kalya/Desktop/Desktop/ML/lama/lama/outputs_all_images'
augmented_folder = os.path.join(output_folder, 'augmented_images')
mask_folder = os.path.join(output_folder, 'masks')
objects_folder = os.path.join(output_folder, 'extracted_objects')

# Create directories for output, masks, and objects
os.makedirs(output_folder, exist_ok=True)
os.makedirs(augmented_folder, exist_ok=True)
os.makedirs(mask_folder, exist_ok=True)
os.makedirs(objects_folder, exist_ok=True)

# List of all images in the input folder
image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]

# # Bounding box coordinates
# bbox = []
# drawing = False  # Flag to indicate if we're currently drawing the bounding box

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# model = YOLO('yolov8l.pt') '' # Using medium model for potentially better accuracy
model = YOLO("yolo11n-seg.pt")
model.to(device)

# Gaussian noise function
def add_gaussian_noise(image, mean=0, std=25):
    noise = np.random.normal(mean, std, image.shape).astype(np.uint8)
    noisy_image = cv2.add(image, noise)
    return noisy_image

# Process each image in the folder
ctr = 0
for image_file in image_files:
    # Load the image
    image_path = os.path.join(input_folder, image_file)
    image = cv2.imread(image_path)
    clone = image.copy()  # Keep a clone of the original image
    # Resize the image to 640x640 for YOLO
    # resized_image = cv2.resize(image, (640, 640))
    # Object detection with lower confidence threshold
    results = model(image, conf=0.5)
    # Get detections for the first image in results
    detections = results[0].boxes 
    
    # Prepare mask for the detected objects (black background)
    # mask = np.zeros(resized_image.shape[:2], dtype=np.uint8)
    mask = np.zeros(image.shape[:2], dtype=np.uint8)
    
    ctr += 1
    # Loop through each detected object and get the bounding box coordinates
    for i, box in enumerate(detections):
        # Move bounding box data to CPU, then convert to integers
        x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
        print(f"for image number = {image_file} x1 = {x1} y1 = {y1} x2 = {x2} y2 = {y2}")
        confidence = box.conf.cpu().numpy()
        
        # if confidence > 0.2:  # Lower confidence threshold
        # Extract object and save it
        if ctr%2 == 0:
            # obj_image = resized_image[y1:y2, x1:x2]
            # Adding noise to the object image
            # print(f"ctr={ctr}")
            obj_image = image[y1:y2, x1:x2]
            obj_image_with_noise = add_gaussian_noise(obj_image)
            augmented_object_path = os.path.join(objects_folder, f'object_{i}_{os.path.splitext(image_file)[0]}.png')
            cv2.imwrite(augmented_object_path, obj_image_with_noise)

        else:
            # obj_image = resized_image[y1:y2, x1:x2]
            # No noise to the object image
            # print(f"ctr={ctr}")
            obj_image = image[y1:y2, x1:x2]
            obj_path = os.path.join(objects_folder, f'object_{i}_{os.path.splitext(image_file)[0]}.png')
            cv2.imwrite(obj_path, obj_image)
                
        # Draw bounding box on mask to indicate regions of interest (black inside objects)
        mask[y1:y2, x1:x2] = 255  # Black region for detected object on mask

    if ctr%2 == 0:
        # No Gaussian noise to the background image and save it
        # augmented_original_image = add_gaussian_noise(clone)
        clone_image_path = os.path.join(augmented_folder, f'{os.path.splitext(image_file)[0]}.png')
        cv2.imwrite(clone_image_path, clone)
    else:
        # Add Gaussian noise to the background image and save it
        augmented_original_image = add_gaussian_noise(clone)
        augmented_image_path = os.path.join(augmented_folder, f'{os.path.splitext(image_file)[0]}.png')
        cv2.imwrite(augmented_image_path, augmented_original_image)
        

    # Save the mask
    tmp=str(image_file)
    img = tmp.split(".")[0]
    num = tmp.split("e")[-1].split(".")[0]
    mask_path = os.path.join(mask_folder, f'{img}_mask{num}.png')
    cv2.imwrite(mask_path, mask)
    
    # Add Gaussian noise to the background image and save it
    # augmented_original_image = add_gaussian_noise(clone)
    # augmented_image_path = os.path.join(augmented_folder, f'{os.path.splitext(image_file)[0]}.png')
    # cv2.imwrite(augmented_image_path, augmented_original_image)
    
    # print(f"Processed {image_file}: Mask saved to {mask_path}, Object saved.")

print("Processing complete for all images.")
# Out:
# 0: 448x640 3 chairs, 1 tv, 1 vase, 42.8ms
# Speed: 4.3ms preprocess, 42.8ms inference, 15.6ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000000139.jpg x1 = 6 y1 = 166 x2 = 154 y2 = 263
# for image number = 000000000139.jpg x1 = 293 y1 = 216 x2 = 353 y2 = 321
# for image number = 000000000139.jpg x1 = 549 y1 = 302 x2 = 586 y2 = 401
# for image number = 000000000139.jpg x1 = 391 y1 = 219 x2 = 443 y2 = 307
# for image number = 000000000139.jpg x1 = 361 y1 = 217 x2 = 417 y2 = 311
#
# 0: 640x608 1 bear, 39.1ms
# Speed: 14.9ms preprocess, 39.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
# for image number = 000000000285.jpg x1 = 17 y1 = 68 x2 = 585 y2 = 640
#
# 0: 512x640 2 potted plants, 1 bed, 15.2ms
# Speed: 14.3ms preprocess, 15.2ms inference, 15.7ms postprocess per image at shape (1, 3, 512, 640)
# for image number = 000000000632.jpg x1 = 0 y1 = 279 x2 = 401 y2 = 476
# for image number = 000000000632.jpg x1 = 339 y1 = 214 x2 = 430 y2 = 351
# for image number = 000000000632.jpg x1 = 185 y1 = 130 x2 = 241 y2 = 228
#
# 0: 640x480 1 stop sign, 35.0ms
# Speed: 10.6ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000000724.jpg x1 = 120 y1 = 70 x2 = 255 y2 = 224
#
# 0: 640x448 2 teddy bears, 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000000776.jpg x1 = 0 y1 = 266 x2 = 322 y2 = 639
# for image number = 000000000776.jpg x1 = 155 y1 = 0 x2 = 427 y2 = 539
#
# 0: 448x640 1 person, 1 skis, 27.2ms
# Speed: 2.1ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000000785.jpg x1 = 277 y1 = 43 x2 = 503 y2 = 389
# for image number = 000000000785.jpg x1 = 208 y1 = 364 x2 = 615 y2 = 402
#
# 0: 640x448 1 oven, 1 refrigerator, 30.6ms
# Speed: 0.0ms preprocess, 30.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000000802.jpg x1 = 246 y1 = 189 x2 = 412 y2 = 533
# for image number = 000000000802.jpg x1 = 36 y1 = 286 x2 = 161 y2 = 519
#
# 0: 640x640 2 persons, 1 baseball glove, 19.7ms
# Speed: 4.9ms preprocess, 19.7ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
# for image number = 000000000872.jpg x1 = 157 y1 = 125 x2 = 373 y2 = 611
# for image number = 000000000872.jpg x1 = 370 y1 = 158 x2 = 434 y2 = 198
# for image number = 000000000872.jpg x1 = 292 y1 = 100 x2 = 435 y2 = 561
#
# 0: 448x640 3 persons, 1 tennis racket, 25.2ms
# Speed: 4.0ms preprocess, 25.2ms inference, 4.4ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000000885.jpg x1 = 595 y1 = 27 x2 = 639 y2 = 249
# for image number = 000000000885.jpg x1 = 277 y1 = 187 x2 = 416 y2 = 398
# for image number = 000000000885.jpg x1 = 390 y1 = 268 x2 = 479 y2 = 310
# for image number = 000000000885.jpg x1 = 293 y1 = 82 x2 = 393 y2 = 249
#
# 0: 480x640 10 persons, 1 tennis racket, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000001000.jpg x1 = 505 y1 = 189 x2 = 639 y2 = 479
# for image number = 000000001000.jpg x1 = 118 y1 = 149 x2 = 199 y2 = 383
# for image number = 000000001000.jpg x1 = 409 y1 = 211 x2 = 522 y2 = 479
# for image number = 000000001000.jpg x1 = 265 y1 = 96 x2 = 355 y2 = 409
# for image number = 000000001000.jpg x1 = 328 y1 = 155 x2 = 416 y2 = 471
# for image number = 000000001000.jpg x1 = 189 y1 = 117 x2 = 271 y2 = 394
# for image number = 000000001000.jpg x1 = 40 y1 = 186 x2 = 110 y2 = 395
# for image number = 000000001000.jpg x1 = 390 y1 = 160 x2 = 465 y2 = 462
# for image number = 000000001000.jpg x1 = 208 y1 = 178 x2 = 287 y2 = 419
# for image number = 000000001000.jpg x1 = 436 y1 = 108 x2 = 497 y2 = 224
# for image number = 000000001000.jpg x1 = 197 y1 = 176 x2 = 283 y2 = 334
#
# 0: 448x640 4 persons, 1 handbag, 25.9ms
# Speed: 2.9ms preprocess, 25.9ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000001268.jpg x1 = 500 y1 = 90 x2 = 639 y2 = 424
# for image number = 000000001268.jpg x1 = 401 y1 = 205 x2 = 468 y2 = 294
# for image number = 000000001268.jpg x1 = 492 y1 = 195 x2 = 596 y2 = 400
# for image number = 000000001268.jpg x1 = 0 y1 = 209 x2 = 24 y2 = 280
# for image number = 000000001268.jpg x1 = 20 y1 = 212 x2 = 77 y2 = 285
#
# 0: 640x448 1 person, 1 cell phone, 23.1ms
# Speed: 2.1ms preprocess, 23.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000001296.jpg x1 = 2 y1 = 14 x2 = 427 y2 = 638
# for image number = 000000001296.jpg x1 = 297 y1 = 143 x2 = 372 y2 = 277
#
# 0: 640x480 2 persons, 1 suitcase, 25.1ms
# Speed: 4.4ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000001353.jpg x1 = 139 y1 = 179 x2 = 262 y2 = 376
# for image number = 000000001353.jpg x1 = 67 y1 = 322 x2 = 251 y2 = 455
# for image number = 000000001353.jpg x1 = 209 y1 = 196 x2 = 272 y2 = 278
#
# 0: 512x640 1 cup, 1 cake, 48.8ms
# Speed: 2.9ms preprocess, 48.8ms inference, 4.1ms postprocess per image at shape (1, 3, 512, 640)
# for image number = 000000001425.jpg x1 = 493 y1 = 195 x2 = 639 y2 = 379
# for image number = 000000001425.jpg x1 = 41 y1 = 178 x2 = 437 y2 = 398
#
# 0: 320x640 1 person, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 640)
# for image number = 000000001490.jpg x1 = 451 y1 = 119 x2 = 499 y2 = 241
#
# 0: 480x640 1 tv, 1 laptop, 1 mouse, 2 keyboards, 23.1ms
# Speed: 1.8ms preprocess, 23.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000001503.jpg x1 = 0 y1 = 99 x2 = 125 y2 = 239
# for image number = 000000001503.jpg x1 = 161 y1 = 152 x2 = 316 y2 = 197
# for image number = 000000001503.jpg x1 = 124 y1 = 12 x2 = 242 y2 = 104
# for image number = 000000001503.jpg x1 = 122 y1 = 179 x2 = 158 y2 = 199
# for image number = 000000001503.jpg x1 = 0 y1 = 169 x2 = 102 y2 = 212
#
# 0: 480x640 5 cars, 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000001532.jpg x1 = 0 y1 = 374 x2 = 115 y2 = 479
# for image number = 000000001532.jpg x1 = 428 y1 = 399 x2 = 489 y2 = 452
# for image number = 000000001532.jpg x1 = 222 y1 = 357 x2 = 422 y2 = 479
# for image number = 000000001532.jpg x1 = 201 y1 = 400 x2 = 242 y2 = 430
# for image number = 000000001532.jpg x1 = 103 y1 = 376 x2 = 183 y2 = 440
#
# 0: 640x640 2 persons, 3 buss, 23.2ms
# Speed: 4.7ms preprocess, 23.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# for image number = 000000001584.jpg x1 = 132 y1 = 88 x2 = 521 y2 = 537
# for image number = 000000001584.jpg x1 = 504 y1 = 315 x2 = 569 y2 = 384
# for image number = 000000001584.jpg x1 = 568 y1 = 317 x2 = 611 y2 = 403
# for image number = 000000001584.jpg x1 = 75 y1 = 376 x2 = 97 y2 = 430
# for image number = 000000001584.jpg x1 = 113 y1 = 379 x2 = 129 y2 = 431
#
# 0: 480x640 1 cat, 1 laptop, 23.4ms
# Speed: 4.5ms preprocess, 23.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000001675.jpg x1 = 0 y1 = 7 x2 = 638 y2 = 313
# for image number = 000000001675.jpg x1 = 3 y1 = 302 x2 = 618 y2 = 480
#
# 0: 640x448 2 airplanes, 30.8ms
# Speed: 0.0ms preprocess, 30.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000001761.jpg x1 = 150 y1 = 7 x2 = 224 y2 = 86
# for image number = 000000001761.jpg x1 = 279 y1 = 138 x2 = 333 y2 = 185
#
# 0: 448x640 1 zebra, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000001818.jpg x1 = 31 y1 = 0 x2 = 639 y2 = 419
#
# 0: 448x640 1 chair, 1 bed, 1 dining table, 46.5ms
# Speed: 0.0ms preprocess, 46.5ms inference, 10.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000001993.jpg x1 = 109 y1 = 248 x2 = 227 y2 = 412
# for image number = 000000001993.jpg x1 = 259 y1 = 194 x2 = 615 y2 = 406
# for image number = 000000001993.jpg x1 = 0 y1 = 249 x2 = 152 y2 = 410
#
# 0: 480x640 2 persons, 1 bus, 29.4ms
# Speed: 2.8ms preprocess, 29.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000002006.jpg x1 = 6 y1 = 251 x2 = 48 y2 = 361
# for image number = 000000002006.jpg x1 = 33 y1 = 81 x2 = 603 y2 = 425
# for image number = 000000002006.jpg x1 = 315 y1 = 188 x2 = 375 y2 = 247
#
# 0: 448x640 3 apples, 23.8ms
# Speed: 2.0ms preprocess, 23.8ms inference, 3.7ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000002149.jpg x1 = 335 y1 = 70 x2 = 587 y2 = 317
# for image number = 000000002149.jpg x1 = 0 y1 = 71 x2 = 337 y2 = 394
# for image number = 000000002149.jpg x1 = 0 y1 = 237 x2 = 249 y2 = 396
#
# 0: 480x640 4 persons, 1 baseball bat, 36.0ms
# Speed: 1.2ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000002153.jpg x1 = 279 y1 = 277 x2 = 466 y2 = 444
# for image number = 000000002153.jpg x1 = 173 y1 = 0 x2 = 239 y2 = 120
# for image number = 000000002153.jpg x1 = 369 y1 = 205 x2 = 443 y2 = 382
# for image number = 000000002153.jpg x1 = 273 y1 = 300 x2 = 379 y2 = 443
# for image number = 000000002153.jpg x1 = 410 y1 = 184 x2 = 460 y2 = 215
#
# 0: 448x640 3 wine glasss, 1 knife, 1 bowl, 1 dining table, 19.0ms
# Speed: 3.8ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000002157.jpg x1 = 231 y1 = 49 x2 = 298 y2 = 202
# for image number = 000000002157.jpg x1 = 11 y1 = 169 x2 = 265 y2 = 364
# for image number = 000000002157.jpg x1 = 113 y1 = 20 x2 = 197 y2 = 173
# for image number = 000000002157.jpg x1 = 2 y1 = 64 x2 = 640 y2 = 426
# for image number = 000000002157.jpg x1 = 165 y1 = 64 x2 = 232 y2 = 179
# for image number = 000000002157.jpg x1 = 216 y1 = 312 x2 = 408 y2 = 422
#
# 0: 448x640 1 person, 19.5ms
# Speed: 4.8ms preprocess, 19.5ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000002261.jpg x1 = 283 y1 = 149 x2 = 383 y2 = 276
#
# 0: 416x640 8 persons, 34.2ms
# Speed: 3.7ms preprocess, 34.2ms inference, 3.5ms postprocess per image at shape (1, 3, 416, 640)
# for image number = 000000002299.jpg x1 = 140 y1 = 191 x2 = 211 y2 = 296
# for image number = 000000002299.jpg x1 = 70 y1 = 191 x2 = 134 y2 = 300
# for image number = 000000002299.jpg x1 = 385 y1 = 193 x2 = 457 y2 = 291
# for image number = 000000002299.jpg x1 = 262 y1 = 193 x2 = 330 y2 = 287
# for image number = 000000002299.jpg x1 = 325 y1 = 188 x2 = 389 y2 = 287
# for image number = 000000002299.jpg x1 = 202 y1 = 188 x2 = 268 y2 = 289
# for image number = 000000002299.jpg x1 = 248 y1 = 123 x2 = 294 y2 = 233
# for image number = 000000002299.jpg x1 = 0 y1 = 130 x2 = 46 y2 = 278
#
# 0: 640x480 1 person, 1 wine glass, 2 cups, 1 spoon, 1 bowl, 1 dining table, 31.2ms
# Speed: 3.3ms preprocess, 31.2ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000002431.jpg x1 = 303 y1 = 0 x2 = 431 y2 = 212
# for image number = 000000002431.jpg x1 = 358 y1 = 416 x2 = 455 y2 = 635
# for image number = 000000002431.jpg x1 = 0 y1 = 93 x2 = 457 y2 = 640
# for image number = 000000002431.jpg x1 = 182 y1 = 398 x2 = 382 y2 = 639
# for image number = 000000002431.jpg x1 = 105 y1 = 391 x2 = 227 y2 = 563
# for image number = 000000002431.jpg x1 = 1 y1 = 0 x2 = 79 y2 = 133
# for image number = 000000002431.jpg x1 = 47 y1 = 378 x2 = 177 y2 = 465
#
# 0: 448x640 4 persons, 21.7ms
# Speed: 2.0ms preprocess, 21.7ms inference, 8.8ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000002473.jpg x1 = 436 y1 = 279 x2 = 499 y2 = 381
# for image number = 000000002473.jpg x1 = 246 y1 = 93 x2 = 372 y2 = 239
# for image number = 000000002473.jpg x1 = 117 y1 = 342 x2 = 146 y2 = 386
# for image number = 000000002473.jpg x1 = 31 y1 = 330 x2 = 59 y2 = 354
#
# 0: 640x480 1 person, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000002532.jpg x1 = 186 y1 = 305 x2 = 280 y2 = 477
#
# 0: 480x640 (no detections), 47.7ms
# Speed: 2.0ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 cup, 22.9ms
# Speed: 0.6ms preprocess, 22.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# for image number = 000000002592.jpg x1 = 219 y1 = 33 x2 = 431 y2 = 240
#
# 0: 576x640 4 persons, 39.5ms
# Speed: 2.0ms preprocess, 39.5ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 640)
# for image number = 000000002685.jpg x1 = 162 y1 = 128 x2 = 517 y2 = 548
# for image number = 000000002685.jpg x1 = 316 y1 = 63 x2 = 635 y2 = 438
# for image number = 000000002685.jpg x1 = 396 y1 = 7 x2 = 599 y2 = 331
# for image number = 000000002685.jpg x1 = 277 y1 = 98 x2 = 374 y2 = 231
#
# 0: 480x640 (no detections), 25.1ms
# Speed: 4.1ms preprocess, 25.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x448 1 person, 1 toilet, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000003156.jpg x1 = 0 y1 = 12 x2 = 409 y2 = 639
# for image number = 000000003156.jpg x1 = 280 y1 = 368 x2 = 440 y2 = 618
#
# 0: 384x640 3 persons, 28.8ms
# Speed: 1.8ms preprocess, 28.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# for image number = 000000003255.jpg x1 = 259 y1 = 313 x2 = 274 y2 = 356
# for image number = 000000003255.jpg x1 = 272 y1 = 315 x2 = 292 y2 = 357
# for image number = 000000003255.jpg x1 = 294 y1 = 312 x2 = 314 y2 = 352
#
# 0: 640x640 1 broccoli, 35.9ms
# Speed: 5.1ms preprocess, 35.9ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
# for image number = 000000003501.jpg x1 = 70 y1 = 68 x2 = 256 y2 = 363
#
# 0: 448x640 1 person, 20.3ms
# Speed: 1.0ms preprocess, 20.3ms inference, 6.1ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000003553.jpg x1 = 152 y1 = 2 x2 = 418 y2 = 290
#
# 0: 384x640 2 bananas, 19.1ms
# Speed: 4.1ms preprocess, 19.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# for image number = 000000003661.jpg x1 = 64 y1 = 0 x2 = 421 y2 = 205
# for image number = 000000003661.jpg x1 = 86 y1 = 171 x2 = 543 y2 = 349
#
# 0: 480x640 1 cup, 2 broccolis, 1 carrot, 1 chair, 1 dining table, 23.6ms
# Speed: 2.7ms preprocess, 23.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000003845.jpg x1 = 108 y1 = 0 x2 = 185 y2 = 55
# for image number = 000000003845.jpg x1 = 1 y1 = 0 x2 = 492 y2 = 375
# for image number = 000000003845.jpg x1 = 450 y1 = 0 x2 = 499 y2 = 71
# for image number = 000000003845.jpg x1 = 120 y1 = 206 x2 = 181 y2 = 270
# for image number = 000000003845.jpg x1 = 190 y1 = 183 x2 = 271 y2 = 260
# for image number = 000000003845.jpg x1 = 188 y1 = 253 x2 = 257 y2 = 321
#
# 0: 640x480 3 persons, 1 couch, 31.2ms
# Speed: 2.4ms preprocess, 31.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000003934.jpg x1 = 64 y1 = 146 x2 = 214 y2 = 463
# for image number = 000000003934.jpg x1 = 162 y1 = 84 x2 = 208 y2 = 226
# for image number = 000000003934.jpg x1 = 199 y1 = 110 x2 = 237 y2 = 230
# for image number = 000000003934.jpg x1 = 139 y1 = 213 x2 = 375 y2 = 361
#
# 0: 448x640 5 persons, 1 tie, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000004134.jpg x1 = 226 y1 = 45 x2 = 586 y2 = 420
# for image number = 000000004134.jpg x1 = 44 y1 = 43 x2 = 312 y2 = 421
# for image number = 000000004134.jpg x1 = 394 y1 = 189 x2 = 433 y2 = 361
# for image number = 000000004134.jpg x1 = 2 y1 = 111 x2 = 74 y2 = 259
# for image number = 000000004134.jpg x1 = 470 y1 = 112 x2 = 524 y2 = 179
# for image number = 000000004134.jpg x1 = 574 y1 = 106 x2 = 638 y2 = 243
#
# 0: 640x448 1 person, 1 tie, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000004395.jpg x1 = 0 y1 = 0 x2 = 408 y2 = 635
# for image number = 000000004395.jpg x1 = 175 y1 = 272 x2 = 275 y2 = 639
#
# 0: 480x640 1 chair, 1 couch, 1 tv, 7.4ms
# Speed: 1.2ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000004495.jpg x1 = 3 y1 = 147 x2 = 153 y2 = 329
# for image number = 000000004495.jpg x1 = 201 y1 = 199 x2 = 497 y2 = 374
# for image number = 000000004495.jpg x1 = 190 y1 = 111 x2 = 260 y2 = 178
#
# 0: 640x640 1 person, 1 surfboard, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# for image number = 000000004765.jpg x1 = 208 y1 = 127 x2 = 403 y2 = 386
# for image number = 000000004765.jpg x1 = 244 y1 = 334 x2 = 535 y2 = 419
#
# 0: 480x640 1 cat, 1 laptop, 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000004795.jpg x1 = 0 y1 = 191 x2 = 180 y2 = 479
# for image number = 000000004795.jpg x1 = 159 y1 = 119 x2 = 547 y2 = 479
#
# 0: 480x640 6 persons, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000005001.jpg x1 = 364 y1 = 95 x2 = 525 y2 = 480
# for image number = 000000005001.jpg x1 = 81 y1 = 228 x2 = 189 y2 = 479
# for image number = 000000005001.jpg x1 = 570 y1 = 145 x2 = 639 y2 = 479
# for image number = 000000005001.jpg x1 = 296 y1 = 54 x2 = 355 y2 = 137
# for image number = 000000005001.jpg x1 = 344 y1 = 54 x2 = 405 y2 = 157
# for image number = 000000005001.jpg x1 = 430 y1 = 44 x2 = 506 y2 = 162
#
# 0: 448x640 1 person, 1 bus, 5.7ms
# Speed: 0.0ms preprocess, 5.7ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000005037.jpg x1 = 100 y1 = 21 x2 = 575 y2 = 372
# for image number = 000000005037.jpg x1 = 622 y1 = 216 x2 = 639 y2 = 358
#
# 0: 640x480 1 person, 8.2ms
# Speed: 0.9ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000005060.jpg x1 = 158 y1 = 308 x2 = 324 y2 = 499
#
# 0: 448x640 6 persons, 1 bottle, 1 cell phone, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000005193.jpg x1 = 0 y1 = 86 x2 = 224 y2 = 421
# for image number = 000000005193.jpg x1 = 354 y1 = 221 x2 = 486 y2 = 378
# for image number = 000000005193.jpg x1 = 290 y1 = 168 x2 = 403 y2 = 404
# for image number = 000000005193.jpg x1 = 376 y1 = 99 x2 = 486 y2 = 290
# for image number = 000000005193.jpg x1 = 139 y1 = 113 x2 = 257 y2 = 419
# for image number = 000000005193.jpg x1 = 367 y1 = 92 x2 = 389 y2 = 168
# for image number = 000000005193.jpg x1 = 70 y1 = 173 x2 = 113 y2 = 201
# for image number = 000000005193.jpg x1 = 223 y1 = 64 x2 = 261 y2 = 192
#
# 0: 352x640 1 airplane, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# for image number = 000000005477.jpg x1 = 22 y1 = 102 x2 = 630 y2 = 290
#
# 0: 640x448 1 toilet, 5.8ms
# Speed: 1.0ms preprocess, 5.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000005503.jpg x1 = 0 y1 = 0 x2 = 274 y2 = 498
#
# 0: 640x448 1 person, 6.4ms
# Speed: 0.0ms preprocess, 6.4ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000005529.jpg x1 = 97 y1 = 126 x2 = 254 y2 = 435
#
# 0: 480x640 4 persons, 2 tennis rackets, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000005586.jpg x1 = 131 y1 = 170 x2 = 200 y2 = 225
# for image number = 000000005586.jpg x1 = 142 y1 = 68 x2 = 175 y2 = 157
# for image number = 000000005586.jpg x1 = 272 y1 = 69 x2 = 293 y2 = 111
# for image number = 000000005586.jpg x1 = 291 y1 = 60 x2 = 302 y2 = 102
# for image number = 000000005586.jpg x1 = 115 y1 = 80 x2 = 135 y2 = 89
# for image number = 000000005586.jpg x1 = 130 y1 = 93 x2 = 153 y2 = 102
#
# 0: 384x640 2 bowls, 8.2ms
# Speed: 0.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# for image number = 000000005600.jpg x1 = 123 y1 = 0 x2 = 376 y2 = 176
# for image number = 000000005600.jpg x1 = 211 y1 = 138 x2 = 524 y2 = 357
#
# 0: 448x640 5 sheeps, 7.0ms
# Speed: 0.9ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000005992.jpg x1 = 25 y1 = 125 x2 = 237 y2 = 369
# for image number = 000000005992.jpg x1 = 557 y1 = 222 x2 = 639 y2 = 424
# for image number = 000000005992.jpg x1 = 206 y1 = 159 x2 = 502 y2 = 424
# for image number = 000000005992.jpg x1 = 422 y1 = 125 x2 = 577 y2 = 410
# for image number = 000000005992.jpg x1 = 558 y1 = 164 x2 = 639 y2 = 291
#
# 0: 544x640 1 banana, 1 apple, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# for image number = 000000006012.jpg x1 = 199 y1 = 243 x2 = 440 y2 = 471
# for image number = 000000006012.jpg x1 = 90 y1 = 23 x2 = 309 y2 = 501
#
# 0: 352x640 1 car, 1 train, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
# for image number = 000000006040.jpg x1 = 60 y1 = 84 x2 = 602 y2 = 308
# for image number = 000000006040.jpg x1 = 0 y1 = 180 x2 = 29 y2 = 219
#
# 0: 448x640 (no detections), 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 person, 6.7ms
# Speed: 0.2ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000006460.jpg x1 = 276 y1 = 137 x2 = 331 y2 = 209
#
# 0: 448x640 8 persons, 1 baseball glove, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000006471.jpg x1 = 17 y1 = 142 x2 = 127 y2 = 322
# for image number = 000000006471.jpg x1 = 266 y1 = 72 x2 = 352 y2 = 298
# for image number = 000000006471.jpg x1 = 86 y1 = 187 x2 = 240 y2 = 322
# for image number = 000000006471.jpg x1 = 215 y1 = 231 x2 = 242 y2 = 263
# for image number = 000000006471.jpg x1 = 91 y1 = 71 x2 = 155 y2 = 140
# for image number = 000000006471.jpg x1 = 212 y1 = 72 x2 = 264 y2 = 129
# for image number = 000000006471.jpg x1 = 168 y1 = 73 x2 = 218 y2 = 132
# for image number = 000000006471.jpg x1 = 25 y1 = 98 x2 = 69 y2 = 146
# for image number = 000000006471.jpg x1 = 402 y1 = 58 x2 = 451 y2 = 114
#
# 0: 512x640 (no detections), 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 3 cars, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# for image number = 000000006723.jpg x1 = 171 y1 = 201 x2 = 196 y2 = 222
# for image number = 000000006723.jpg x1 = 282 y1 = 201 x2 = 301 y2 = 212
# for image number = 000000006723.jpg x1 = 204 y1 = 201 x2 = 241 y2 = 229
#
# 0: 640x480 3 persons, 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000006763.jpg x1 = 4 y1 = 115 x2 = 365 y2 = 496
# for image number = 000000006763.jpg x1 = 0 y1 = 213 x2 = 45 y2 = 335
# for image number = 000000006763.jpg x1 = 1 y1 = 96 x2 = 231 y2 = 481
#
# 0: 448x640 7 persons, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000006771.jpg x1 = 537 y1 = 173 x2 = 639 y2 = 422
# for image number = 000000006771.jpg x1 = 384 y1 = 160 x2 = 572 y2 = 422
# for image number = 000000006771.jpg x1 = 164 y1 = 110 x2 = 448 y2 = 422
# for image number = 000000006771.jpg x1 = 386 y1 = 131 x2 = 481 y2 = 231
# for image number = 000000006771.jpg x1 = 538 y1 = 126 x2 = 639 y2 = 312
# for image number = 000000006771.jpg x1 = 0 y1 = 2 x2 = 84 y2 = 410
# for image number = 000000006771.jpg x1 = 65 y1 = 185 x2 = 220 y2 = 349
#
# 0: 640x448 (no detections), 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 480x640 1 person, 1 elephant, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000006894.jpg x1 = 319 y1 = 27 x2 = 639 y2 = 479
# for image number = 000000006894.jpg x1 = 0 y1 = 86 x2 = 307 y2 = 475
#
# 0: 480x640 5 persons, 2 frisbees, 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000006954.jpg x1 = 460 y1 = 233 x2 = 603 y2 = 366
# for image number = 000000006954.jpg x1 = 0 y1 = 104 x2 = 164 y2 = 450
# for image number = 000000006954.jpg x1 = 143 y1 = 137 x2 = 254 y2 = 317
# for image number = 000000006954.jpg x1 = 363 y1 = 150 x2 = 440 y2 = 327
# for image number = 000000006954.jpg x1 = 375 y1 = 121 x2 = 639 y2 = 381
# for image number = 000000006954.jpg x1 = 204 y1 = 125 x2 = 363 y2 = 372
# for image number = 000000006954.jpg x1 = 250 y1 = 229 x2 = 355 y2 = 339
#
# 0: 640x480 1 person, 1 umbrella, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000007088.jpg x1 = 181 y1 = 204 x2 = 273 y2 = 463
# for image number = 000000007088.jpg x1 = 81 y1 = 172 x2 = 309 y2 = 265
#
# 0: 448x640 3 elephants, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000007108.jpg x1 = 396 y1 = 79 x2 = 638 y2 = 421
# for image number = 000000007108.jpg x1 = 120 y1 = 23 x2 = 461 y2 = 421
# for image number = 000000007108.jpg x1 = 338 y1 = 1 x2 = 501 y2 = 99
#
# 0: 512x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# for image number = 000000007278.jpg x1 = 191 y1 = 60 x2 = 311 y2 = 156
#
# 0: 384x640 4 persons, 2 horses, 5.9ms
# Speed: 1.0ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# for image number = 000000007281.jpg x1 = 389 y1 = 132 x2 = 462 y2 = 299
# for image number = 000000007281.jpg x1 = 339 y1 = 189 x2 = 425 y2 = 358
# for image number = 000000007281.jpg x1 = 470 y1 = 176 x2 = 537 y2 = 357
# for image number = 000000007281.jpg x1 = 552 y1 = 192 x2 = 566 y2 = 223
# for image number = 000000007281.jpg x1 = 460 y1 = 120 x2 = 547 y2 = 288
# for image number = 000000007281.jpg x1 = 1 y1 = 228 x2 = 31 y2 = 270
#
# 0: 448x640 1 motorcycle, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000007386.jpg x1 = 104 y1 = 8 x2 = 598 y2 = 390
#
# 0: 480x640 3 persons, 1 kite, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000007511.jpg x1 = 376 y1 = 241 x2 = 508 y2 = 479
# for image number = 000000007511.jpg x1 = 204 y1 = 124 x2 = 222 y2 = 161
# for image number = 000000007511.jpg x1 = 236 y1 = 279 x2 = 250 y2 = 307
# for image number = 000000007511.jpg x1 = 270 y1 = 274 x2 = 282 y2 = 304
#
# 0: 480x640 3 bottles, 1 bowl, 1 refrigerator, 1 vase, 7.9ms
# Speed: 0.0ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000007574.jpg x1 = 0 y1 = 166 x2 = 102 y2 = 378
# for image number = 000000007574.jpg x1 = 205 y1 = 56 x2 = 230 y2 = 92
# for image number = 000000007574.jpg x1 = 480 y1 = 299 x2 = 508 y2 = 380
# for image number = 000000007574.jpg x1 = 500 y1 = 308 x2 = 532 y2 = 385
# for image number = 000000007574.jpg x1 = 293 y1 = 295 x2 = 345 y2 = 388
# for image number = 000000007574.jpg x1 = 104 y1 = 68 x2 = 148 y2 = 89
#
# 0: 480x640 2 kites, 6.2ms
# Speed: 1.0ms preprocess, 6.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000007784.jpg x1 = 14 y1 = 85 x2 = 331 y2 = 353
# for image number = 000000007784.jpg x1 = 83 y1 = 85 x2 = 332 y2 = 307
#
# 0: 448x640 2 beds, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000007795.jpg x1 = 0 y1 = 190 x2 = 455 y2 = 422
# for image number = 000000007795.jpg x1 = 117 y1 = 189 x2 = 481 y2 = 363
#
# 0: 448x640 3 persons, 1 motorcycle, 6.2ms
# Speed: 0.0ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000007816.jpg x1 = 239 y1 = 153 x2 = 468 y2 = 359
# for image number = 000000007816.jpg x1 = 247 y1 = 35 x2 = 294 y2 = 143
# for image number = 000000007816.jpg x1 = 269 y1 = 79 x2 = 421 y2 = 234
# for image number = 000000007816.jpg x1 = 489 y1 = 56 x2 = 519 y2 = 161
#
# 0: 448x640 1 chair, 2 vases, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000007818.jpg x1 = 6 y1 = 260 x2 = 114 y2 = 309
# for image number = 000000007818.jpg x1 = 289 y1 = 233 x2 = 364 y2 = 313
# for image number = 000000007818.jpg x1 = 399 y1 = 185 x2 = 444 y2 = 272
#
# 0: 640x640 2 clocks, 9.4ms
# Speed: 0.0ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# for image number = 000000007888.jpg x1 = 324 y1 = 245 x2 = 463 y2 = 399
# for image number = 000000007888.jpg x1 = 184 y1 = 250 x2 = 300 y2 = 417
#
# 0: 640x448 1 person, 2 skateboards, 7.5ms
# Speed: 1.1ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000007977.jpg x1 = 106 y1 = 149 x2 = 264 y2 = 420
# for image number = 000000007977.jpg x1 = 192 y1 = 346 x2 = 268 y2 = 426
# for image number = 000000007977.jpg x1 = 192 y1 = 370 x2 = 262 y2 = 426
#
# 0: 384x640 (no detections), 6.9ms
# Speed: 1.1ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 3 persons, 1 tie, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000008021.jpg x1 = 244 y1 = 98 x2 = 438 y2 = 363
# for image number = 000000008021.jpg x1 = 0 y1 = 257 x2 = 311 y2 = 479
# for image number = 000000008021.jpg x1 = 316 y1 = 198 x2 = 340 y2 = 303
# for image number = 000000008021.jpg x1 = 445 y1 = 286 x2 = 640 y2 = 479
#
# 0: 480x640 2 persons, 1 motorcycle, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000008211.jpg x1 = 325 y1 = 204 x2 = 405 y2 = 351
# for image number = 000000008211.jpg x1 = 412 y1 = 183 x2 = 478 y2 = 345
# for image number = 000000008211.jpg x1 = 9 y1 = 159 x2 = 265 y2 = 314
#
# 0: 640x640 1 bowl, 6.6ms
# Speed: 2.7ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# for image number = 000000008277.jpg x1 = 30 y1 = 37 x2 = 461 y2 = 362
#
# 0: 448x640 1 person, 1 tie, 6.6ms
# Speed: 1.3ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000008532.jpg x1 = 158 y1 = 10 x2 = 639 y2 = 421
# for image number = 000000008532.jpg x1 = 419 y1 = 370 x2 = 494 y2 = 425
#
# 0: 640x640 1 fork, 4 pizzas, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 640)
# for image number = 000000008629.jpg x1 = 20 y1 = 57 x2 = 411 y2 = 382
# for image number = 000000008629.jpg x1 = 227 y1 = 431 x2 = 412 y2 = 618
# for image number = 000000008629.jpg x1 = 429 y1 = 21 x2 = 620 y2 = 186
# for image number = 000000008629.jpg x1 = 432 y1 = 243 x2 = 619 y2 = 394
# for image number = 000000008629.jpg x1 = 594 y1 = 284 x2 = 621 y2 = 339
#
# 0: 480x640 2 persons, 5.8ms
# Speed: 1.8ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000008690.jpg x1 = 128 y1 = 21 x2 = 352 y2 = 394
# for image number = 000000008690.jpg x1 = 319 y1 = 78 x2 = 510 y2 = 477
#
# 0: 448x640 2 traffic lights, 8.9ms
# Speed: 0.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000008762.jpg x1 = 164 y1 = 104 x2 = 186 y2 = 145
# for image number = 000000008762.jpg x1 = 57 y1 = 85 x2 = 79 y2 = 146
#
# 0: 448x640 1 person, 6.9ms
# Speed: 0.6ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000008844.jpg x1 = 355 y1 = 56 x2 = 584 y2 = 286
#
# 0: 544x640 1 bicycle, 1 fire hydrant, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# for image number = 000000008899.jpg x1 = 139 y1 = 398 x2 = 190 y2 = 492
# for image number = 000000008899.jpg x1 = 0 y1 = 351 x2 = 72 y2 = 456
#
# 0: 448x640 3 persons, 1 frisbee, 12.0ms
# Speed: 3.4ms preprocess, 12.0ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000009378.jpg x1 = 188 y1 = 215 x2 = 358 y2 = 256
# for image number = 000000009378.jpg x1 = 66 y1 = 45 x2 = 472 y2 = 386
# for image number = 000000009378.jpg x1 = 424 y1 = 334 x2 = 482 y2 = 389
# for image number = 000000009378.jpg x1 = 537 y1 = 290 x2 = 593 y2 = 388
#
# 0: 480x640 8 persons, 3 cups, 7 laptops, 23.9ms
# Speed: 0.0ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000009400.jpg x1 = 63 y1 = 309 x2 = 261 y2 = 479
# for image number = 000000009400.jpg x1 = 261 y1 = 226 x2 = 590 y2 = 479
# for image number = 000000009400.jpg x1 = 446 y1 = 95 x2 = 639 y2 = 365
# for image number = 000000009400.jpg x1 = 311 y1 = 86 x2 = 457 y2 = 287
# for image number = 000000009400.jpg x1 = 0 y1 = 83 x2 = 103 y2 = 184
# for image number = 000000009400.jpg x1 = 0 y1 = 216 x2 = 59 y2 = 311
# for image number = 000000009400.jpg x1 = 0 y1 = 173 x2 = 101 y2 = 260
# for image number = 000000009400.jpg x1 = 143 y1 = 93 x2 = 280 y2 = 263
# for image number = 000000009400.jpg x1 = 277 y1 = 60 x2 = 368 y2 = 184
# for image number = 000000009400.jpg x1 = 343 y1 = 225 x2 = 499 y2 = 340
# for image number = 000000009400.jpg x1 = 347 y1 = 230 x2 = 404 y2 = 362
# for image number = 000000009400.jpg x1 = 83 y1 = 211 x2 = 214 y2 = 278
# for image number = 000000009400.jpg x1 = 252 y1 = 417 x2 = 317 y2 = 479
# for image number = 000000009400.jpg x1 = 251 y1 = 379 x2 = 326 y2 = 479
# for image number = 000000009400.jpg x1 = 562 y1 = 46 x2 = 614 y2 = 127
# for image number = 000000009400.jpg x1 = 84 y1 = 210 x2 = 223 y2 = 310
# for image number = 000000009400.jpg x1 = 451 y1 = 66 x2 = 532 y2 = 227
# for image number = 000000009400.jpg x1 = 525 y1 = 412 x2 = 639 y2 = 479
#
# 0: 640x576 1 person, 1 umbrella, 22.9ms
# Speed: 8.9ms preprocess, 22.9ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 576)
# for image number = 000000009448.jpg x1 = 0 y1 = 1 x2 = 551 y2 = 392
# for image number = 000000009448.jpg x1 = 134 y1 = 102 x2 = 377 y2 = 639
#
# 0: 480x640 2 persons, 1 tv, 1 mouse, 1 keyboard, 34.1ms
# Speed: 2.7ms preprocess, 34.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000009483.jpg x1 = 38 y1 = 62 x2 = 176 y2 = 480
# for image number = 000000009483.jpg x1 = 304 y1 = 315 x2 = 425 y2 = 362
# for image number = 000000009483.jpg x1 = 456 y1 = 211 x2 = 579 y2 = 353
# for image number = 000000009483.jpg x1 = 375 y1 = 361 x2 = 409 y2 = 379
# for image number = 000000009483.jpg x1 = 304 y1 = 74 x2 = 376 y2 = 224
#
# 0: 448x640 5 persons, 1 bottle, 1 cup, 2 bowls, 1 clock, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000009590.jpg x1 = 0 y1 = 57 x2 = 245 y2 = 413
# for image number = 000000009590.jpg x1 = 384 y1 = 169 x2 = 456 y2 = 263
# for image number = 000000009590.jpg x1 = 136 y1 = 157 x2 = 232 y2 = 286
# for image number = 000000009590.jpg x1 = 252 y1 = 176 x2 = 326 y2 = 253
# for image number = 000000009590.jpg x1 = 504 y1 = 112 x2 = 639 y2 = 285
# for image number = 000000009590.jpg x1 = 348 y1 = 270 x2 = 385 y2 = 310
# for image number = 000000009590.jpg x1 = 424 y1 = 274 x2 = 472 y2 = 306
# for image number = 000000009590.jpg x1 = 382 y1 = 272 x2 = 420 y2 = 300
# for image number = 000000009590.jpg x1 = 177 y1 = 96 x2 = 199 y2 = 126
# for image number = 000000009590.jpg x1 = 428 y1 = 227 x2 = 449 y2 = 276
#
# 0: 480x640 1 person, 1 truck, 1 fire hydrant, 21.6ms
# Speed: 8.4ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000009769.jpg x1 = 552 y1 = 262 x2 = 562 y2 = 278
# for image number = 000000009769.jpg x1 = 147 y1 = 186 x2 = 464 y2 = 373
# for image number = 000000009769.jpg x1 = 136 y1 = 201 x2 = 183 y2 = 276
#
# 0: 640x576 1 person, 1 tv, 31.1ms
# Speed: 2.0ms preprocess, 31.1ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 576)
# for image number = 000000009772.jpg x1 = 421 y1 = 91 x2 = 517 y2 = 187
# for image number = 000000009772.jpg x1 = 275 y1 = 231 x2 = 331 y2 = 354
#
# 0: 480x640 2 persons, 1 car, 2 suitcases, 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000009891.jpg x1 = 204 y1 = 95 x2 = 345 y2 = 421
# for image number = 000000009891.jpg x1 = 76 y1 = 101 x2 = 202 y2 = 291
# for image number = 000000009891.jpg x1 = 162 y1 = 240 x2 = 307 y2 = 402
# for image number = 000000009891.jpg x1 = 324 y1 = 86 x2 = 639 y2 = 311
# for image number = 000000009891.jpg x1 = 421 y1 = 243 x2 = 493 y2 = 334
#
# 0: 480x640 1 bowl, 27.9ms
# Speed: 0.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000009914.jpg x1 = 0 y1 = 148 x2 = 200 y2 = 360
#
# 0: 448x640 1 bed, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000010092.jpg x1 = 89 y1 = 55 x2 = 438 y2 = 415
#
# 0: 384x640 1 car, 1 cat, 36.6ms
# Speed: 0.9ms preprocess, 36.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# for image number = 000000010363.jpg x1 = 244 y1 = 102 x2 = 466 y2 = 245
# for image number = 000000010363.jpg x1 = 11 y1 = 29 x2 = 639 y2 = 354
#
# 0: 640x640 1 cup, 23.8ms
# Speed: 3.4ms preprocess, 23.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# for image number = 000000010583.jpg x1 = 0 y1 = 33 x2 = 33 y2 = 250
#
# 0: 480x640 3 persons, 17.7ms
# Speed: 3.5ms preprocess, 17.7ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000010707.jpg x1 = 415 y1 = 0 x2 = 599 y2 = 479
# for image number = 000000010707.jpg x1 = 236 y1 = 146 x2 = 402 y2 = 451
# for image number = 000000010707.jpg x1 = 347 y1 = 196 x2 = 475 y2 = 447
#
# 0: 448x640 1 person, 1 baseball glove, 24.8ms
# Speed: 0.0ms preprocess, 24.8ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000010764.jpg x1 = 218 y1 = 79 x2 = 484 y2 = 400
# for image number = 000000010764.jpg x1 = 425 y1 = 209 x2 = 484 y2 = 281
#
# 0: 480x640 1 toilet, 1 sink, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000010977.jpg x1 = 241 y1 = 254 x2 = 299 y2 = 341
# for image number = 000000010977.jpg x1 = 340 y1 = 217 x2 = 418 y2 = 252
#
# 0: 480x640 1 bed, 20.2ms
# Speed: 2.2ms preprocess, 20.2ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000010995.jpg x1 = 119 y1 = 212 x2 = 640 y2 = 479
#
# 0: 544x640 2 persons, 1 tie, 24.1ms
# Speed: 4.4ms preprocess, 24.1ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
# for image number = 000000011051.jpg x1 = 250 y1 = 81 x2 = 636 y2 = 529
# for image number = 000000011051.jpg x1 = 2 y1 = 5 x2 = 395 y2 = 528
# for image number = 000000011051.jpg x1 = 193 y1 = 199 x2 = 255 y2 = 427
#
# 0: 480x640 1 stop sign, 24.2ms
# Speed: 2.9ms preprocess, 24.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000011122.jpg x1 = 250 y1 = 164 x2 = 329 y2 = 242
#
# 0: 480x640 1 person, 2 bicycles, 1 motorcycle, 31.1ms
# Speed: 0.5ms preprocess, 31.1ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000011149.jpg x1 = 198 y1 = 92 x2 = 422 y2 = 276
# for image number = 000000011149.jpg x1 = 413 y1 = 0 x2 = 499 y2 = 319
# for image number = 000000011149.jpg x1 = 0 y1 = 78 x2 = 141 y2 = 351
# for image number = 000000011149.jpg x1 = 88 y1 = 60 x2 = 199 y2 = 226
#
# 0: 448x640 3 persons, 1 bicycle, 4 cars, 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 9.5ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000011197.jpg x1 = 306 y1 = 111 x2 = 361 y2 = 252
# for image number = 000000011197.jpg x1 = 401 y1 = 154 x2 = 486 y2 = 194
# for image number = 000000011197.jpg x1 = 321 y1 = 294 x2 = 639 y2 = 422
# for image number = 000000011197.jpg x1 = 14 y1 = 113 x2 = 55 y2 = 186
# for image number = 000000011197.jpg x1 = 173 y1 = 141 x2 = 216 y2 = 168
# for image number = 000000011197.jpg x1 = 137 y1 = 152 x2 = 162 y2 = 164
# for image number = 000000011197.jpg x1 = 554 y1 = 166 x2 = 604 y2 = 193
# for image number = 000000011197.jpg x1 = 563 y1 = 146 x2 = 590 y2 = 192
#
# 0: 480x640 5 persons, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000011511.jpg x1 = 88 y1 = 44 x2 = 132 y2 = 190
# for image number = 000000011511.jpg x1 = 317 y1 = 19 x2 = 461 y2 = 366
# for image number = 000000011511.jpg x1 = 155 y1 = 35 x2 = 191 y2 = 170
# for image number = 000000011511.jpg x1 = 36 y1 = 67 x2 = 86 y2 = 190
# for image number = 000000011511.jpg x1 = 224 y1 = 26 x2 = 409 y2 = 369
#
# 0: 640x480 1 stop sign, 22.0ms
# Speed: 4.3ms preprocess, 22.0ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000011615.jpg x1 = 262 y1 = 444 x2 = 378 y2 = 619
#
# 0: 640x480 3 persons, 1 suitcase, 32.7ms
# Speed: 2.1ms preprocess, 32.7ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000011699.jpg x1 = 0 y1 = 403 x2 = 285 y2 = 639
# for image number = 000000011699.jpg x1 = 215 y1 = 99 x2 = 433 y2 = 640
# for image number = 000000011699.jpg x1 = 54 y1 = 79 x2 = 227 y2 = 424
# for image number = 000000011699.jpg x1 = 0 y1 = 241 x2 = 73 y2 = 403
#
# 0: 448x640 3 zebras, 23.8ms
# Speed: 2.3ms preprocess, 23.8ms inference, 3.3ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000011760.jpg x1 = 41 y1 = 99 x2 = 215 y2 = 388
# for image number = 000000011760.jpg x1 = 454 y1 = 91 x2 = 606 y2 = 414
# for image number = 000000011760.jpg x1 = 267 y1 = 92 x2 = 386 y2 = 398
#
# 0: 640x448 (no detections), 27.4ms
# Speed: 3.6ms preprocess, 27.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 448x640 2 sheeps, 27.6ms
# Speed: 4.3ms preprocess, 27.6ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000012062.jpg x1 = 176 y1 = 70 x2 = 567 y2 = 283
# for image number = 000000012062.jpg x1 = 338 y1 = 258 x2 = 638 y2 = 423
#
# 0: 448x640 6 persons, 24.4ms
# Speed: 3.5ms preprocess, 24.4ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000012120.jpg x1 = 483 y1 = 209 x2 = 545 y2 = 324
# for image number = 000000012120.jpg x1 = 5 y1 = 235 x2 = 60 y2 = 309
# for image number = 000000012120.jpg x1 = 88 y1 = 112 x2 = 121 y2 = 178
# for image number = 000000012120.jpg x1 = 93 y1 = 217 x2 = 126 y2 = 290
# for image number = 000000012120.jpg x1 = 178 y1 = 83 x2 = 198 y2 = 135
# for image number = 000000012120.jpg x1 = 453 y1 = 114 x2 = 478 y2 = 162
#
# 0: 640x480 1 person, 31.6ms
# Speed: 0.9ms preprocess, 31.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000012280.jpg x1 = 141 y1 = 241 x2 = 184 y2 = 369
#
# 0: 640x480 1 person, 4 cups, 1 knife, 2 pizzas, 1 dining table, 29.4ms
# Speed: 3.6ms preprocess, 29.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000012576.jpg x1 = 0 y1 = 379 x2 = 433 y2 = 639
# for image number = 000000012576.jpg x1 = 364 y1 = 209 x2 = 456 y2 = 372
# for image number = 000000012576.jpg x1 = 139 y1 = 202 x2 = 218 y2 = 345
# for image number = 000000012576.jpg x1 = 0 y1 = 109 x2 = 477 y2 = 636
# for image number = 000000012576.jpg x1 = 380 y1 = 108 x2 = 423 y2 = 171
# for image number = 000000012576.jpg x1 = 272 y1 = 117 x2 = 311 y2 = 192
# for image number = 000000012576.jpg x1 = 381 y1 = 406 x2 = 479 y2 = 566
# for image number = 000000012576.jpg x1 = 187 y1 = 13 x2 = 303 y2 = 153
# for image number = 000000012576.jpg x1 = 293 y1 = 190 x2 = 480 y2 = 227
#
# 0: 640x480 5 persons, 1 baseball glove, 42.8ms
# Speed: 2.7ms preprocess, 42.8ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000012639.jpg x1 = 18 y1 = 310 x2 = 174 y2 = 552
# for image number = 000000012639.jpg x1 = 196 y1 = 204 x2 = 318 y2 = 517
# for image number = 000000012639.jpg x1 = 411 y1 = 127 x2 = 463 y2 = 296
# for image number = 000000012639.jpg x1 = 131 y1 = 348 x2 = 187 y2 = 400
# for image number = 000000012639.jpg x1 = 306 y1 = 133 x2 = 332 y2 = 211
# for image number = 000000012639.jpg x1 = 96 y1 = 193 x2 = 141 y2 = 251
#
# 0: 480x640 1 banana, 22.9ms
# Speed: 2.4ms preprocess, 22.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000012667.jpg x1 = 283 y1 = 52 x2 = 430 y2 = 288
#
# 0: 448x640 10 persons, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000012670.jpg x1 = 475 y1 = 242 x2 = 612 y2 = 426
# for image number = 000000012670.jpg x1 = 134 y1 = 266 x2 = 267 y2 = 428
# for image number = 000000012670.jpg x1 = 350 y1 = 297 x2 = 440 y2 = 426
# for image number = 000000012670.jpg x1 = 382 y1 = 227 x2 = 506 y2 = 426
# for image number = 000000012670.jpg x1 = 249 y1 = 264 x2 = 362 y2 = 426
# for image number = 000000012670.jpg x1 = 0 y1 = 268 x2 = 68 y2 = 427
# for image number = 000000012670.jpg x1 = 219 y1 = 154 x2 = 297 y2 = 343
# for image number = 000000012670.jpg x1 = 271 y1 = 48 x2 = 338 y2 = 238
# for image number = 000000012670.jpg x1 = 45 y1 = 232 x2 = 152 y2 = 426
# for image number = 000000012670.jpg x1 = 583 y1 = 92 x2 = 639 y2 = 331
#
# 0: 640x480 1 person, 1 horse, 18.0ms
# Speed: 6.8ms preprocess, 18.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000012748.jpg x1 = 0 y1 = 46 x2 = 240 y2 = 564
# for image number = 000000012748.jpg x1 = 222 y1 = 190 x2 = 479 y2 = 633
#
# 0: 640x480 (no detections), 24.3ms
# Speed: 5.3ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 448x640 1 person, 1 motorcycle, 26.7ms
# Speed: 2.2ms preprocess, 26.7ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000013177.jpg x1 = 304 y1 = 56 x2 = 613 y2 = 414
# for image number = 000000013177.jpg x1 = 0 y1 = 3 x2 = 226 y2 = 418
#
# 0: 640x448 1 person, 1 skateboard, 33.6ms
# Speed: 1.3ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000013201.jpg x1 = 92 y1 = 94 x2 = 322 y2 = 472
# for image number = 000000013201.jpg x1 = 108 y1 = 424 x2 = 179 y2 = 524
#
# 0: 448x640 6 persons, 4 frisbees, 21.4ms
# Speed: 3.2ms preprocess, 21.4ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000013291.jpg x1 = 283 y1 = 143 x2 = 498 y2 = 296
# for image number = 000000013291.jpg x1 = 42 y1 = 64 x2 = 166 y2 = 300
# for image number = 000000013291.jpg x1 = 182 y1 = 197 x2 = 216 y2 = 232
# for image number = 000000013291.jpg x1 = 90 y1 = 151 x2 = 136 y2 = 194
# for image number = 000000013291.jpg x1 = 252 y1 = 165 x2 = 295 y2 = 206
# for image number = 000000013291.jpg x1 = 219 y1 = 134 x2 = 305 y2 = 284
# for image number = 000000013291.jpg x1 = 156 y1 = 137 x2 = 246 y2 = 266
# for image number = 000000013291.jpg x1 = 215 y1 = 186 x2 = 251 y2 = 222
# for image number = 000000013291.jpg x1 = 24 y1 = 165 x2 = 31 y2 = 181
# for image number = 000000013291.jpg x1 = 241 y1 = 135 x2 = 313 y2 = 284
#
# 0: 448x640 1 airplane, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000013348.jpg x1 = 19 y1 = 140 x2 = 575 y2 = 288
#
# 0: 448x640 2 persons, 1 car, 1 bench, 2 skateboards, 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000013546.jpg x1 = 468 y1 = 5 x2 = 574 y2 = 252
# for image number = 000000013546.jpg x1 = 456 y1 = 46 x2 = 475 y2 = 101
# for image number = 000000013546.jpg x1 = 503 y1 = 202 x2 = 543 y2 = 255
# for image number = 000000013546.jpg x1 = 472 y1 = 77 x2 = 519 y2 = 115
# for image number = 000000013546.jpg x1 = 205 y1 = 114 x2 = 298 y2 = 144
# for image number = 000000013546.jpg x1 = 506 y1 = 203 x2 = 554 y2 = 257
#
# 0: 448x640 1 cake, 19.7ms
# ...
# for image number = 000000575970.jpg x1 = 337 y1 = 256 x2 = 384 y2 = 284
# for image number = 000000575970.jpg x1 = 300 y1 = 246 x2 = 324 y2 = 280
# for image number = 000000575970.jpg x1 = 408 y1 = 256 x2 = 439 y2 = 278
#
# 0: 480x640 2 persons, 1 skis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000576031.jpg x1 = 231 y1 = 83 x2 = 400 y2 = 478
# for image number = 000000576031.jpg x1 = 200 y1 = 428 x2 = 564 y2 = 479
# for image number = 000000576031.jpg x1 = 157 y1 = 111 x2 = 212 y2 = 224
#
# 0: 448x640 1 person, 1 horse, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000576052.jpg x1 = 402 y1 = 149 x2 = 492 y2 = 379
# for image number = 000000576052.jpg x1 = 422 y1 = 90 x2 = 514 y2 = 253
#
# 0: 640x480 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000576566.jpg x1 = 110 y1 = 22 x2 = 346 y2 = 447
#
# 0: 448x640 1 person, 1 kite, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000576654.jpg x1 = 503 y1 = 230 x2 = 581 y2 = 382
# for image number = 000000576654.jpg x1 = 243 y1 = 35 x2 = 495 y2 = 159
#
# 0: 448x640 1 person, 2 horses, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000576955.jpg x1 = 280 y1 = 98 x2 = 438 y2 = 340
# for image number = 000000576955.jpg x1 = 236 y1 = 27 x2 = 270 y2 = 119
# for image number = 000000576955.jpg x1 = 307 y1 = 52 x2 = 378 y2 = 250
#
# 0: 416x640 4 zebras, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# for image number = 000000577149.jpg x1 = 342 y1 = 159 x2 = 565 y2 = 382
# for image number = 000000577149.jpg x1 = 192 y1 = 146 x2 = 252 y2 = 316
# for image number = 000000577149.jpg x1 = 110 y1 = 143 x2 = 186 y2 = 299
# for image number = 000000577149.jpg x1 = 417 y1 = 162 x2 = 478 y2 = 229
#
# 0: 448x640 2 benchs, 1 bird, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000577182.jpg x1 = 305 y1 = 181 x2 = 340 y2 = 217
# for image number = 000000577182.jpg x1 = 1 y1 = 181 x2 = 639 y2 = 420
# for image number = 000000577182.jpg x1 = 0 y1 = 1 x2 = 40 y2 = 161
#
# 0: 448x640 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x448 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 480x640 1 vase, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000577735.jpg x1 = 394 y1 = 258 x2 = 497 y2 = 447
#
# 0: 448x640 2 giraffes, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000577862.jpg x1 = 185 y1 = 22 x2 = 542 y2 = 420
# for image number = 000000577862.jpg x1 = 414 y1 = 40 x2 = 605 y2 = 398
#
# 0: 448x640 3 persons, 1 sports ball, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000577864.jpg x1 = 137 y1 = 0 x2 = 396 y2 = 336
# for image number = 000000577864.jpg x1 = 503 y1 = 0 x2 = 553 y2 = 67
# for image number = 000000577864.jpg x1 = 294 y1 = 0 x2 = 486 y2 = 169
# for image number = 000000577864.jpg x1 = 526 y1 = 84 x2 = 555 y2 = 112
#
# 0: 544x640 5 persons, 4 cars, 1 handbag, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# for image number = 000000577932.jpg x1 = 182 y1 = 227 x2 = 268 y2 = 281
# for image number = 000000577932.jpg x1 = 297 y1 = 232 x2 = 374 y2 = 477
# for image number = 000000577932.jpg x1 = 41 y1 = 219 x2 = 102 y2 = 270
# for image number = 000000577932.jpg x1 = 499 y1 = 255 x2 = 639 y2 = 542
# for image number = 000000577932.jpg x1 = 435 y1 = 233 x2 = 460 y2 = 329
# for image number = 000000577932.jpg x1 = 384 y1 = 233 x2 = 412 y2 = 331
# for image number = 000000577932.jpg x1 = 152 y1 = 206 x2 = 170 y2 = 260
# for image number = 000000577932.jpg x1 = 287 y1 = 260 x2 = 348 y2 = 366
# for image number = 000000577932.jpg x1 = 234 y1 = 234 x2 = 310 y2 = 489
# for image number = 000000577932.jpg x1 = 0 y1 = 198 x2 = 12 y2 = 212
#
# 0: 448x640 1 person, 1 kite, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000577959.jpg x1 = 203 y1 = 278 x2 = 216 y2 = 311
# for image number = 000000577959.jpg x1 = 379 y1 = 69 x2 = 472 y2 = 185
#
# 0: 448x640 1 truck, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.1ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000577976.jpg x1 = 509 y1 = 219 x2 = 639 y2 = 336
#
# 0: 480x640 1 train, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000578093.jpg x1 = 0 y1 = 226 x2 = 294 y2 = 403
#
# 0: 640x448 1 bird, 1 cat, 6.6ms
# Speed: 0.8ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000578236.jpg x1 = 174 y1 = 223 x2 = 393 y2 = 470
# for image number = 000000578236.jpg x1 = 276 y1 = 156 x2 = 362 y2 = 201
#
# 0: 480x640 6 persons, 1 remote, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000578489.jpg x1 = 84 y1 = 92 x2 = 277 y2 = 395
# for image number = 000000578489.jpg x1 = 359 y1 = 115 x2 = 534 y2 = 479
# for image number = 000000578489.jpg x1 = 511 y1 = 65 x2 = 588 y2 = 362
# for image number = 000000578489.jpg x1 = 537 y1 = 24 x2 = 639 y2 = 479
# for image number = 000000578489.jpg x1 = 344 y1 = 100 x2 = 448 y2 = 373
# for image number = 000000578489.jpg x1 = 373 y1 = 50 x2 = 459 y2 = 165
# for image number = 000000578489.jpg x1 = 351 y1 = 195 x2 = 403 y2 = 238
#
# 0: 320x640 3 couchs, 2 potted plants, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# for image number = 000000578500.jpg x1 = 495 y1 = 114 x2 = 639 y2 = 285
# for image number = 000000578500.jpg x1 = 272 y1 = 148 x2 = 466 y2 = 240
# for image number = 000000578500.jpg x1 = 423 y1 = 25 x2 = 464 y2 = 113
# for image number = 000000578500.jpg x1 = 0 y1 = 145 x2 = 136 y2 = 244
# for image number = 000000578500.jpg x1 = 327 y1 = 59 x2 = 357 y2 = 119
#
# 0: 480x640 1 person, 1 bed, 1 laptop, 7.7ms
# Speed: 0.0ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000578545.jpg x1 = 184 y1 = 92 x2 = 431 y2 = 375
# for image number = 000000578545.jpg x1 = 1 y1 = 111 x2 = 624 y2 = 474
# for image number = 000000578545.jpg x1 = 358 y1 = 225 x2 = 520 y2 = 360
#
# 0: 448x640 1 person, 1 motorcycle, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000578792.jpg x1 = 176 y1 = 89 x2 = 593 y2 = 323
# for image number = 000000578792.jpg x1 = 142 y1 = 83 x2 = 486 y2 = 205
#
# 0: 640x480 1 person, 1 spoon, 3 bowls, 1 dining table, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000578871.jpg x1 = 72 y1 = 4 x2 = 297 y2 = 288
# for image number = 000000578871.jpg x1 = 275 y1 = 224 x2 = 355 y2 = 284
# for image number = 000000578871.jpg x1 = 158 y1 = 458 x2 = 309 y2 = 603
# for image number = 000000578871.jpg x1 = 0 y1 = 229 x2 = 478 y2 = 629
# for image number = 000000578871.jpg x1 = 135 y1 = 327 x2 = 334 y2 = 457
# for image number = 000000578871.jpg x1 = 275 y1 = 331 x2 = 382 y2 = 397
#
# 0: 640x608 1 cup, 1 vase, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 608)
# for image number = 000000578922.jpg x1 = 316 y1 = 503 x2 = 427 y2 = 638
# for image number = 000000578922.jpg x1 = 176 y1 = 446 x2 = 278 y2 = 639
#
# 0: 480x640 1 train, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000578967.jpg x1 = 4 y1 = 150 x2 = 639 y2 = 463
#
# 0: 448x640 4 persons, 7 cups, 1 dining table, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000579070.jpg x1 = 278 y1 = 25 x2 = 471 y2 = 265
# for image number = 000000579070.jpg x1 = 104 y1 = 34 x2 = 289 y2 = 230
# for image number = 000000579070.jpg x1 = 0 y1 = 89 x2 = 80 y2 = 264
# for image number = 000000579070.jpg x1 = 0 y1 = 206 x2 = 634 y2 = 424
# for image number = 000000579070.jpg x1 = 458 y1 = 243 x2 = 502 y2 = 305
# for image number = 000000579070.jpg x1 = 330 y1 = 261 x2 = 355 y2 = 297
# for image number = 000000579070.jpg x1 = 0 y1 = 0 x2 = 104 y2 = 96
# for image number = 000000579070.jpg x1 = 60 y1 = 233 x2 = 101 y2 = 291
# for image number = 000000579070.jpg x1 = 222 y1 = 223 x2 = 288 y2 = 336
# for image number = 000000579070.jpg x1 = 2 y1 = 280 x2 = 35 y2 = 314
# for image number = 000000579070.jpg x1 = 195 y1 = 219 x2 = 215 y2 = 246
# for image number = 000000579070.jpg x1 = 144 y1 = 229 x2 = 169 y2 = 257
#
# 0: 448x640 1 broccoli, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000579091.jpg x1 = 469 y1 = 267 x2 = 639 y2 = 386
#
# 0: 480x640 1 airplane, 8.6ms
# Speed: 0.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000579158.jpg x1 = 1 y1 = 1 x2 = 628 y2 = 432
#
# 0: 640x480 2 persons, 1 kite, 11.2ms
# Speed: 0.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000579307.jpg x1 = 177 y1 = 167 x2 = 275 y2 = 324
# for image number = 000000579307.jpg x1 = 253 y1 = 226 x2 = 380 y2 = 639
# for image number = 000000579307.jpg x1 = 153 y1 = 294 x2 = 345 y2 = 476
#
# 0: 512x640 1 person, 2 dogs, 0.0ms
# Speed: 0.8ms preprocess, 0.0ms inference, 8.1ms postprocess per image at shape (1, 3, 512, 640)
# for image number = 000000579321.jpg x1 = 98 y1 = 0 x2 = 336 y2 = 214
# for image number = 000000579321.jpg x1 = 209 y1 = 60 x2 = 633 y2 = 333
# for image number = 000000579321.jpg x1 = 210 y1 = 66 x2 = 480 y2 = 331
#
# 0: 448x640 1 person, 1 boat, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000579635.jpg x1 = 433 y1 = 259 x2 = 465 y2 = 313
# for image number = 000000579635.jpg x1 = 186 y1 = 84 x2 = 230 y2 = 150
#
# 0: 416x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# for image number = 000000579655.jpg x1 = 181 y1 = 3 x2 = 639 y2 = 394
#
# 0: 384x640 1 person, 1 train, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# for image number = 000000579818.jpg x1 = 0 y1 = 87 x2 = 520 y2 = 217
# for image number = 000000579818.jpg x1 = 427 y1 = 111 x2 = 442 y2 = 133
#
# 0: 448x640 1 stop sign, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000579893.jpg x1 = 352 y1 = 126 x2 = 492 y2 = 329
#
# 0: 640x480 1 broccoli, 1 pizza, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000579900.jpg x1 = 0 y1 = 37 x2 = 374 y2 = 462
# for image number = 000000579900.jpg x1 = 208 y1 = 142 x2 = 266 y2 = 201
#
# 0: 640x576 1 person, 1 car, 1 motorcycle, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 9.9ms postprocess per image at shape (1, 3, 640, 576)
# for image number = 000000579902.jpg x1 = 389 y1 = 198 x2 = 555 y2 = 638
# for image number = 000000579902.jpg x1 = 207 y1 = 162 x2 = 384 y2 = 487
# for image number = 000000579902.jpg x1 = 198 y1 = 323 x2 = 363 y2 = 579
#
# 0: 448x640 1 chair, 1 tv, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000579970.jpg x1 = 371 y1 = 106 x2 = 406 y2 = 152
# for image number = 000000579970.jpg x1 = 264 y1 = 148 x2 = 317 y2 = 206
#
# 0: 480x640 3 persons, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000580197.jpg x1 = 65 y1 = 99 x2 = 323 y2 = 479
# for image number = 000000580197.jpg x1 = 491 y1 = 83 x2 = 639 y2 = 480
# for image number = 000000580197.jpg x1 = 187 y1 = 306 x2 = 444 y2 = 479
#
# 0: 448x640 1 person, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000580294.jpg x1 = 384 y1 = 2 x2 = 639 y2 = 441
#
# 0: 640x448 2 chairs, 1 couch, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 448)
# for image number = 000000580410.jpg x1 = 237 y1 = 202 x2 = 311 y2 = 345
# for image number = 000000580410.jpg x1 = 0 y1 = 243 x2 = 132 y2 = 503
# for image number = 000000580410.jpg x1 = 126 y1 = 291 x2 = 194 y2 = 418
#
# 0: 448x640 2 cars, 3 cows, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000580418.jpg x1 = 69 y1 = 244 x2 = 365 y2 = 425
# for image number = 000000580418.jpg x1 = 425 y1 = 218 x2 = 590 y2 = 422
# for image number = 000000580418.jpg x1 = 0 y1 = 174 x2 = 166 y2 = 424
# for image number = 000000580418.jpg x1 = 597 y1 = 255 x2 = 639 y2 = 363
# for image number = 000000580418.jpg x1 = 150 y1 = 206 x2 = 247 y2 = 260
#
# 0: 448x640 1 fire hydrant, 0.0ms
# Speed: 10.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000580757.jpg x1 = 334 y1 = 66 x2 = 568 y2 = 411
#
# 0: 480x640 1 person, 1 skateboard, 1 donut, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000581062.jpg x1 = 130 y1 = 53 x2 = 195 y2 = 165
# for image number = 000000581062.jpg x1 = 181 y1 = 247 x2 = 266 y2 = 313
# for image number = 000000581062.jpg x1 = 127 y1 = 155 x2 = 170 y2 = 170
#
# 0: 480x640 2 giraffes, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000581100.jpg x1 = 233 y1 = 143 x2 = 396 y2 = 400
# for image number = 000000581100.jpg x1 = 374 y1 = 156 x2 = 456 y2 = 380
#
# 0: 640x480 1 person, 1 hot dog, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000581206.jpg x1 = 39 y1 = 144 x2 = 344 y2 = 379
# for image number = 000000581206.jpg x1 = 0 y1 = 0 x2 = 472 y2 = 223
#
# 0: 384x640 1 person, 1 cell phone, 9.8ms
# Speed: 0.0ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# for image number = 000000581317.jpg x1 = 412 y1 = 55 x2 = 613 y2 = 351
# for image number = 000000581317.jpg x1 = 406 y1 = 141 x2 = 429 y2 = 178
#
# 0: 640x640 1 person, 1 skateboard, 0.0ms
# Speed: 10.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 640)
# for image number = 000000581357.jpg x1 = 257 y1 = 91 x2 = 481 y2 = 340
# for image number = 000000581357.jpg x1 = 226 y1 = 301 x2 = 374 y2 = 374
#
# 0: 448x640 1 clock, 40.0ms
# Speed: 0.0ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 640)
# for image number = 000000581482.jpg x1 = 405 y1 = 206 x2 = 510 y2 = 303
#
# 0: 640x480 1 toilet, 50.0ms
# Speed: 0.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# for image number = 000000581615.jpg x1 = 142 y1 = 384 x2 = 324 y2 = 624
#
# 0: 480x640 3 bananas, 34.9ms
# Speed: 10.0ms preprocess, 34.9ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# for image number = 000000581781.jpg x1 = 0 y1 = 187 x2 = 132 y2 = 343
# for image number = 000000581781.jpg x1 = 135 y1 = 216 x2 = 426 y2 = 317
# for image number = 000000581781.jpg x1 = 43 y1 = 78 x2 = 177 y2 = 215
# Processing complete for all images.
